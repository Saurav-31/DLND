# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:35, 201kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
for i, j in get_batches(['my','name','is','saurav','i', 'work','at','bosch','.'],4):
    print(i,'\n',j)
# Out:
# ['my', 'my', 'name', 'name', 'is', 'is', 'is', 'saurav', 'saurav', 'saurav']
#  ['is', 'name', 'is', 'my', 'saurav', 'name', 'my', 'is', 'name', 'my']
# ['i', 'work', 'work', 'work', 'at', 'at', 'at', 'bosch', 'bosch', 'bosch']
#  ['work', 'bosch', 'at', 'i', 'bosch', 'work', 'i', 'work', 'at', 'i']

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6413 0.0721 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6200 0.0674 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5564 0.0700 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5640 0.0681 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5298 0.0677 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5457 0.0670 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5616 0.0670 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5213 0.0668 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4846 0.0664 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4457 0.0661 sec/batch
# Nearest to for: mcleod, gorges, rosh, arnaz, throws, lymphocytes, marvelous, silting,
# Nearest to which: takers, scorpions, helge, physicians, python, aegeas, separation, refreshing,
# Nearest to on: diverted, beryllium, jardine, chanter, rann, big, or, equates,
# Nearest to no: ta, arrigo, abscesses, senate, ipf, eritrean, ed, erupt,
# Nearest to b: abms, pomerania, moviegoers, andrewes, beatle, perses, hilkiah, gutar,
# Nearest to american: mesa, ina, crm, scalable, solanaceae, klans, downtime, qatar,
# Nearest to however: larry, water, bootlegs, tatsam, liars, sufism, translates, frankness,
# Nearest to system: fiendish, brawl, benzoate, emporis, cosgrave, soiled, owen, macquarie,
# Nearest to stage: canvases, blige, accu, twofold, wankel, craftsman, mrna, saturation,
# Nearest to centre: horned, ashcroft, marcellus, mistress, cobe, installments, convicted, winfrey,
# Nearest to notes: minter, style, refreshed, shipman, selfish, immaturity, responding, gard,
# Nearest to discovered: apogee, azores, impermanent, flowed, mondeo, quinlan, arapaho, hellraiser,
# Nearest to mean: fridays, barthes, quiver, ditch, sciences, hearn, cretans, charmed,
# Nearest to except: flier, sinhala, sigourney, casa, demarcation, defamation, daring, dago,
# Nearest to arts: fundamentalist, tankage, thanksgiving, hemorrhagic, fromm, albornoz, reexports, satirize,
# Nearest to rise: vig, blogger, curve, minims, capacitor, anthropoid, ink, paternalism,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4735 0.0667 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3690 0.0653 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3451 0.0656 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2734 0.0656 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1813 0.0654 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1682 0.0654 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1099 0.0654 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0696 0.0655 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0120 0.0656 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9872 0.0656 sec/batch
# Nearest to for: mcleod, gorges, mainstream, extra, arnaz, ducts, rosh, tally,
# Nearest to which: physicians, takers, helge, likely, python, scorpions, separation, soft,
# Nearest to on: diverted, or, big, equates, relegated, perceptions, both, lanes,
# Nearest to no: ta, senate, ed, arrigo, rebel, throughout, values, seen,
# Nearest to b: abms, ciar, pomerania, outline, svoboda, moviegoers, stations, astronomical,
# Nearest to american: two, legally, mesa, democrats, seven, klans, ina, san,
# Nearest to however: water, larry, till, release, repertoire, liars, colors, scanned,
# Nearest to system: brawl, fiendish, rough, benzoate, emporis, different, owen, cosgrave,
# Nearest to stage: craftsman, canvases, blige, mrna, swimming, accu, distant, cpu,
# Nearest to centre: mistress, convicted, ashcroft, cobe, ed, procession, winfrey, benevolent,
# Nearest to notes: style, responding, storyline, selfish, minter, refreshed, modern, adopts,
# Nearest to discovered: flowed, impermanent, visitors, mondeo, starvation, wasn, apogee, quinlan,
# Nearest to mean: sciences, fridays, cretans, presided, ditch, appeared, barthes, pares,
# Nearest to except: defamation, therefore, daring, demarcation, flier, sigourney, casa, messianic,
# Nearest to arts: fundamentalist, hemorrhagic, thanksgiving, tankage, dmca, hint, off, exhibition,
# Nearest to rise: blogger, curve, vig, dreaming, baker, ink, project, reservations,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9286 0.0665 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8901 0.0658 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8677 0.0658 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8601 0.0662 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8165 0.0654 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8321 0.0657 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8251 0.0660 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7885 0.0659 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7769 0.0660 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7769 0.0661 sec/batch
# Nearest to for: mcleod, gorges, arnaz, throws, mainstream, rosh, lenticular, extra,
# Nearest to which: takers, helge, physicians, separation, python, likely, scorpions, attitude,
# Nearest to on: diverted, big, gymnasium, rann, equates, thorough, jardine, or,
# Nearest to no: senate, arrigo, ta, ed, eritrean, synthesizer, reunify, appoint,
# Nearest to b: abms, outline, ciar, pomerania, stations, svoboda, georges, fontaine,
# Nearest to american: two, seven, births, democrats, ina, mesa, liked, legally,
# Nearest to however: larry, water, translates, repertoire, charming, liars, colors, scanned,
# Nearest to system: impart, fiendish, emporis, rough, benzoate, brawl, cosgrave, demonstrations,
# Nearest to stage: canvases, craftsman, blige, mrna, accu, saturation, pythons, swimming,
# Nearest to centre: convicted, mistress, ashcroft, procession, ed, cobe, winfrey, benevolent,
# Nearest to notes: style, selfish, responding, lincoln, minter, storyline, adopts, delicate,
# Nearest to discovered: flowed, apogee, mondeo, visitors, wasn, tokens, impermanent, stored,
# Nearest to mean: sciences, cretans, fridays, canton, barthes, ditch, pares, presided,
# Nearest to except: demarcation, defamation, therefore, daring, sigourney, casa, flier, messianic,
# Nearest to arts: fundamentalist, hemorrhagic, thanksgiving, exhibition, hint, reexports, dmca, anointing,
# Nearest to rise: curve, blogger, reservations, vig, advertising, ink, dreaming, imperfect,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7588 0.0668 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7588 0.0673 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7053 0.0664 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7100 0.0663 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7299 0.0665 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7269 0.0662 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7092 0.0660 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7290 0.0658 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7146 0.0660 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6431 0.0661 sec/batch
# Nearest to for: mcleod, gorges, arnaz, throws, rosh, commodities, chameleon, ferry,
# Nearest to which: takers, helge, scorpions, physicians, python, separation, likely, attitude,
# Nearest to on: diverted, rann, jardine, ono, beryllium, preventive, swiftly, big,
# Nearest to no: arrigo, senate, synthesizer, monoid, eritrean, reunify, ta, abscesses,
# Nearest to b: abms, actress, ciar, georges, pomerania, outline, nine, svoboda,
# Nearest to american: two, seven, births, swaim, producer, six, governor, klans,
# Nearest to however: sufism, larry, water, repertoire, charming, translates, bootlegs, houghton,
# Nearest to system: impart, emporis, different, fiendish, rough, brawl, soiled, infinite,
# Nearest to stage: canvases, blige, craftsman, cpu, hobart, mrna, accu, pythons,
# Nearest to centre: ashcroft, convicted, mistress, procession, horned, cobe, marcellus, benevolent,
# Nearest to notes: style, minter, storyline, selfish, vows, lincoln, responding, shipman,
# Nearest to discovered: flowed, apogee, mondeo, wasn, penetrates, starvation, stored, impermanent,
# Nearest to mean: sciences, cretans, fridays, barthes, ditch, canton, basel, charmed,
# Nearest to except: demarcation, defamation, therefore, sigourney, daring, casa, flier, salutation,
# Nearest to arts: fundamentalist, thanksgiving, hint, hemorrhagic, sumatra, exhibition, joked, tankage,
# Nearest to rise: curve, blogger, ink, ayutthaya, vig, advertising, reservations, dreaming,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6683 0.0670 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6647 0.0661 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6431 0.0663 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6316 0.0660 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6244 0.0664 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6358 0.0663 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6022 0.0471 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5445 0.0666 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5106 0.0665 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4861 0.0659 sec/batch
# Nearest to for: mcleod, throws, arnaz, gorges, lymphocytes, obligated, workflow, diligent,
# Nearest to which: takers, scorpions, helge, python, likely, physicians, separation, attitude,
# Nearest to on: diverted, rann, swiftly, beryllium, jardine, stairs, chanter, big,
# Nearest to no: arrigo, synthesizer, sesame, reunify, monoid, eritrean, ta, erupt,
# Nearest to b: actress, georges, abms, nine, four, singer, ciar, guitarist,
# Nearest to american: two, seven, births, producer, journalist, guitarist, swaim, stevens,
# Nearest to however: sufism, charming, translates, water, bootlegs, buddies, tatsam, repertoire,
# Nearest to system: impart, emporis, different, soiled, rough, fiendish, macquarie, brawl,
# Nearest to stage: canvases, blige, craftsman, wankel, ares, hobart, pollination, twofold,
# Nearest to centre: ashcroft, mistress, horned, procession, convicted, marcellus, eicher, neuroscientist,
# Nearest to notes: minter, selfish, shipman, gard, style, immaturity, storyline, vows,
# Nearest to discovered: flowed, apogee, starvation, azores, ceramics, mondeo, impermanent, penetrates,
# Nearest to mean: fridays, sciences, cretans, ditch, barthes, apollonius, charmed, canton,
# Nearest to except: demarcation, therefore, defamation, sigourney, casa, flier, daring, salutation,
# Nearest to arts: fundamentalist, sumatra, thanksgiving, hint, hemorrhagic, joked, exhibition, administers,
# Nearest to rise: curve, ink, blogger, ayutthaya, vig, fellatio, embattled, carcass,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4972 0.0671 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5023 0.0670 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4539 0.0668 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5404 0.0663 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5121 0.0677 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4973 0.0661 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4655 0.0670 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4029 0.0665 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4185 0.0669 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4433 0.0673 sec/batch
# Nearest to for: mcleod, throws, diligent, lymphocytes, arnaz, workflow, gorges, enzyme,
# Nearest to which: takers, scorpions, python, helge, likely, avars, physicians, separation,
# Nearest to on: chanter, diverted, rann, beryllium, stairs, big, jardine, balhae,
# Nearest to no: arrigo, synthesizer, reunify, eritrean, gda, sesame, monoid, discredit,
# Nearest to b: abms, georges, ciar, fontaine, kath, actress, outline, svoboda,
# Nearest to american: two, births, producer, swaim, mesa, seven, stevens, ina,
# Nearest to however: sufism, buddies, bootlegs, charming, repertoire, tatsam, guid, translates,
# Nearest to system: soiled, impart, different, macquarie, emporis, rough, rubies, memorialized,
# Nearest to stage: blige, canvases, wankel, ares, craftsman, nicer, hobart, sociobiology,
# Nearest to centre: ashcroft, horned, eicher, cobe, mistress, bisecting, procession, neuroscientist,
# Nearest to notes: minter, style, selfish, shipman, immaturity, storyline, tripling, appreciating,
# Nearest to discovered: flowed, apogee, azores, starvation, ceramics, impermanent, dissimilar, wasn,
# Nearest to mean: fridays, cretans, apollonius, barthes, sciences, ditch, charmed, hearn,
# Nearest to except: demarcation, therefore, sigourney, defamation, flier, casa, sinhala, salutation,
# Nearest to arts: sumatra, fundamentalist, exhibition, hint, thanksgiving, joked, hemorrhagic, tankage,
# Nearest to rise: ayutthaya, blogger, ink, vig, curve, anthropoid, carthage, bowing,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4119 0.0683 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4041 0.0685 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4417 0.0672 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3855 0.0674 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4033 0.0668 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4348 0.0668 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3942 0.0671 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3795 0.0670 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4178 0.0667 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3877 0.0678 sec/batch
# Nearest to for: lymphocytes, throws, diligent, workflow, mcleod, gorges, obligated, commodities,
# Nearest to which: takers, avars, python, scorpions, likely, physicians, helge, toponyms,
# Nearest to on: chanter, diverted, big, rann, stairs, beryllium, lanes, jardine,
# Nearest to no: arrigo, scientific, sesame, gda, synthesizer, undisclosed, monoid, meaningful,
# Nearest to b: abms, georges, e, four, fontaine, actress, svoboda, ciar,
# Nearest to american: two, producer, swaim, stevens, births, seven, gabriel, guitarist,
# Nearest to however: sufism, bootlegs, buddies, charming, translates, tatsam, guid, centralised,
# Nearest to system: soiled, impart, rubies, rough, memorialized, emporis, mundus, files,
# Nearest to stage: blige, ares, canvases, wankel, pythons, sociobiology, nicer, craftsman,
# Nearest to centre: horned, ashcroft, eicher, cobe, chattahoochee, babington, tripe, bisecting,
# Nearest to notes: minter, shipman, style, tripling, selfish, koalas, immaturity, storyline,
# Nearest to discovered: flowed, starvation, ceramics, apogee, azores, impermanent, dissimilar, penetrates,
# Nearest to mean: fridays, cretans, sciences, apollonius, barthes, quiver, charmed, ditch,
# Nearest to except: demarcation, therefore, dago, sigourney, defamation, salutation, flier, casa,
# Nearest to arts: sumatra, fundamentalist, exhibition, thanksgiving, hint, joked, fromm, administers,
# Nearest to rise: ayutthaya, vig, carthage, blogger, anthropoid, dreaming, ink, curve,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3718 0.0677 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3974 0.0672 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3509 0.0668 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3771 0.0668 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3988 0.0669 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3683 0.0669 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3820 0.0662 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3883 0.0671 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3286 0.0693 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3252 0.0678 sec/batch
# Nearest to for: diligent, gorges, lymphocytes, mcleod, throws, lenticular, recognizing, limpbizkit,
# Nearest to which: takers, python, avars, likely, helge, scorpions, toponyms, separation,
# Nearest to on: chanter, lanes, stairs, beryllium, diverted, rann, big, balhae,
# Nearest to no: arrigo, sesame, scientific, synthesizer, meaningful, monoid, gda, abuse,
# Nearest to b: abms, e, georges, outline, kath, mathematician, fontaine, four,
# Nearest to american: two, swaim, stevens, births, producer, gabriel, postseason, mesa,
# Nearest to however: buddies, sufism, charming, tatsam, guid, centralised, translates, bootlegs,
# Nearest to system: soiled, files, impart, rubies, mundus, rom, emporis, voting,
# Nearest to stage: canvases, wankel, ares, blige, sociobiology, pythons, nicer, craftsman,
# Nearest to centre: horned, ashcroft, bisecting, eicher, mothe, singapore, chattahoochee, babington,
# Nearest to notes: minter, style, shipman, immaturity, selfish, bugle, storyline, mesoamerica,
# Nearest to discovered: flowed, ceramics, starvation, apogee, dissimilar, impermanent, equidistant, wasn,
# Nearest to mean: fridays, apollonius, cretans, barthes, sciences, inlays, ditch, charmed,
# Nearest to except: demarcation, sigourney, casa, therefore, dago, salutation, sinhala, flier,
# Nearest to arts: sumatra, exhibition, fundamentalist, fromm, thanksgiving, joked, hint, administers,
# Nearest to rise: ayutthaya, vig, carthage, calonne, anthropoid, bonaparte, potential, embattled,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3758 0.0682 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3105 0.0666 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3405 0.0683 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3655 0.0680 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3907 0.0686 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2798 0.0678 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3376 0.0666 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3477 0.0670 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2215 0.0670 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3200 0.0665 sec/batch
# Nearest to for: diligent, commodities, limpbizkit, workflow, throws, gorges, gnp, mcleod,
# Nearest to which: takers, python, avars, helge, toponyms, scorpions, likely, copernicanism,
# Nearest to on: lanes, chanter, beryllium, rann, stairs, balhae, transsexualism, big,
# Nearest to no: arrigo, sesame, scientific, reunify, gda, centralised, synthesizer, acutely,
# Nearest to b: abms, georges, e, physicist, mathematician, statesman, four, kath,
# Nearest to american: two, stevens, swaim, producer, cyclist, gabriel, journalist, births,
# Nearest to however: buddies, sufism, charming, centralised, tatsam, guid, stabs, translates,
# Nearest to system: soiled, rubies, impart, files, noncommutative, access, mundus, voting,
# Nearest to stage: canvases, ares, blige, wankel, pythons, sociobiology, eyepiece, beadwork,
# Nearest to centre: ashcroft, mothe, bisecting, chattahoochee, horned, singapore, procession, eicher,
# Nearest to notes: minter, shipman, selfish, immaturity, appreciating, style, bugle, mesoamerica,
# Nearest to discovered: flowed, ceramics, starvation, apogee, equidistant, dissimilar, impermanent, azores,
# Nearest to mean: fridays, cretans, sciences, inlays, persecute, apollonius, metrizable, furnishings,
# Nearest to except: demarcation, sigourney, sinhala, casa, dago, therefore, salutation, defamation,
# Nearest to arts: sumatra, exhibition, fundamentalist, administers, hint, joked, reasoner, photocopier,
# Nearest to rise: ayutthaya, anthropoid, vig, embattled, potential, calonne, carthage, carcass,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3169 0.0681 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2945 0.0665 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3486 0.0279 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2601 0.0663 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2483 0.0663 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1909 0.0665 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2052 0.0666 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2219 0.0694 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2347 0.0696 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1833 0.0659 sec/batch
# Nearest to for: diligent, commodities, gnp, throws, workflow, limpbizkit, recognizing, idl,
# Nearest to which: takers, avars, python, toponyms, helge, scorpions, copernicanism, likely,
# Nearest to on: lanes, chanter, beryllium, rann, stairs, big, transsexualism, balhae,
# Nearest to no: arrigo, acutely, sesame, abuse, meaningful, centralised, bankrupt, reunify,
# Nearest to b: abms, georges, e, statesman, physicist, mathematician, christoph, four,
# Nearest to american: swaim, stevens, two, mesa, producer, harris, crm, cyclist,
# Nearest to however: buddies, centralised, guid, sufism, bootlegs, stabs, charming, arminius,
# Nearest to system: soiled, files, voting, mundus, rubies, moruroa, access, rom,
# Nearest to stage: ares, blige, canvases, beadwork, wankel, pythons, sociobiology, mmu,
# Nearest to centre: ashcroft, mothe, bisecting, singapore, dobruja, linking, eicher, steam,
# Nearest to notes: minter, immaturity, selfish, shipman, appreciating, style, koalas, tripling,
# Nearest to discovered: flowed, ceramics, starvation, impermanent, equidistant, apogee, scalp, azores,
# Nearest to mean: fridays, inlays, apollonius, cretans, tautological, barthes, lecturers, furnishings,
# Nearest to except: demarcation, sigourney, casa, sinhala, dago, therefore, ligeantia, salutation,
# Nearest to arts: sumatra, exhibition, administers, fundamentalist, joked, reasoner, hint, fromm,
# Nearest to rise: ayutthaya, anthropoid, embattled, vig, potential, calonne, conquer, carthage,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2490 0.0673 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2186 0.0660 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2347 0.0661 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1286 0.0668 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1867 0.0666 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1523 0.0666 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1649 0.0662 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1712 0.0665 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1959 0.0664 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1525 0.0665 sec/batch
# Nearest to for: diligent, recognizing, enzyme, douala, mcleod, throws, commodities, ices,
# Nearest to which: takers, avars, python, helge, toponyms, likely, completely, scorpions,
# Nearest to on: chanter, lanes, stairs, beryllium, rann, big, sterilisation, statecraft,
# Nearest to no: arrigo, acutely, meaningful, centralised, undisclosed, yojimbo, senate, abuse,
# Nearest to b: abms, e, outline, infty, kath, bigg, georges, rightarrow,
# Nearest to american: swaim, mesa, stevens, two, births, crm, harris, producer,
# Nearest to however: buddies, bootlegs, stabs, exceptionally, in, guid, centralised, composites,
# Nearest to system: voting, soiled, files, moruroa, mundus, macquarie, acquiring, onerous,
# Nearest to stage: beadwork, ares, blige, canvases, pythons, wankel, sociobiology, eyepiece,
# Nearest to centre: mothe, quantization, ashcroft, linking, bisecting, dobruja, procession, hectares,
# Nearest to notes: selfish, immaturity, minter, appreciating, shipman, modern, mesoamerica, cyrillic,
# Nearest to discovered: flowed, ceramics, starvation, equidistant, impermanent, dissimilar, scalp, cvn,
# Nearest to mean: fridays, apollonius, tautological, inlays, lecturers, barthes, cretans, persecute,
# Nearest to except: demarcation, sigourney, dago, therefore, sinhala, defamation, messianic, ligeantia,
# Nearest to arts: sumatra, administers, exhibition, fundamentalist, veneto, fromm, reasoner, joked,
# Nearest to rise: ayutthaya, potential, anthropoid, vig, paternalism, embattled, perpetuation, carthage,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1674 0.0674 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2069 0.0663 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1698 0.0669 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1780 0.0665 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1855 0.0662 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1743 0.0663 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1939 0.0664 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1701 0.0666 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1476 0.0668 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1834 0.0663 sec/batch
# Nearest to for: diligent, recognizing, catechumen, commodities, limpbizkit, keenly, mcleod, theoretic,
# Nearest to which: takers, avars, python, toponyms, copernicanism, afforded, helge, parseval,
# Nearest to on: chanter, lanes, stairs, beryllium, jardine, statecraft, rann, transsexualism,
# Nearest to no: arrigo, centralised, acutely, meaningful, sesame, synthesizer, yojimbo, gladiators,
# Nearest to b: abms, e, statesman, physicist, marianne, georges, outline, four,
# Nearest to american: swaim, stevens, cyclist, gabriel, producer, journalist, births, harris,
# Nearest to however: buddies, centralised, in, bootlegs, exceptionally, guid, tatsam, water,
# Nearest to system: voting, soiled, noncommutative, via, files, macquarie, mundus, acquiring,
# Nearest to stage: beadwork, canvases, ares, blige, pythons, wankel, craftsman, sociobiology,
# Nearest to centre: mothe, ashcroft, dobruja, linking, quantization, bisecting, arsenal, hectares,
# Nearest to notes: minter, shipman, selfish, immaturity, style, appreciating, modern, cyrillic,
# Nearest to discovered: flowed, ceramics, starvation, equidistant, dissimilar, scalp, impermanent, occultation,
# Nearest to mean: fridays, cretans, tautological, persecute, inlays, lecturers, apollonius, canton,
# Nearest to except: demarcation, dago, sigourney, therefore, sinhala, ligeantia, atrahasis, antiderivative,
# Nearest to arts: sumatra, exhibition, administers, fundamentalist, reasoner, fromm, joked, hint,
# Nearest to rise: ayutthaya, anthropoid, potential, perpetuation, outcomes, vig, embattled, rale,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2164 0.0671 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1575 0.0660 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1869 0.0661 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2052 0.0660 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1346 0.0661 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1594 0.0667 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1642 0.0663 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1620 0.0664 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1744 0.0660 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2456 0.0662 sec/batch
# Nearest to for: diligent, the, recognizing, catechumen, mcleod, stratton, limpbizkit, commodities,
# Nearest to which: takers, avars, python, copernicanism, toponyms, helge, pushed, led,
# Nearest to on: lanes, chanter, rann, jardine, beryllium, swiftly, calvary, balhae,
# Nearest to no: arrigo, synthesizer, centralised, gladiators, monoid, yojimbo, nats, gda,
# Nearest to b: statesman, abms, e, four, marianne, georges, kath, physicist,
# Nearest to american: swaim, two, cyclist, stevens, harris, producer, journalist, gabriel,
# Nearest to however: centralised, buddies, composites, guid, exceptionally, tatsam, bootlegs, sufism,
# Nearest to system: voting, soiled, noncommutative, macquarie, council, via, onerous, acquiring,
# Nearest to stage: beadwork, canvases, ares, blige, pythons, wankel, craftsman, downbeat,
# Nearest to centre: mothe, dobruja, linking, ashcroft, bisecting, quantization, hectares, procession,
# Nearest to notes: minter, immaturity, shipman, style, appreciating, modern, selfish, gard,
# Nearest to discovered: flowed, ceramics, equidistant, starvation, scalp, dissimilar, occultation, impermanent,
# Nearest to mean: tautological, inlays, metrizable, cretans, fridays, apollonius, monsoon, canton,
# Nearest to except: demarcation, dago, sigourney, casa, messianic, atrahasis, inflectional, sinhala,
# Nearest to arts: sumatra, exhibition, administers, fundamentalist, reasoner, hint, joked, schools,
# Nearest to rise: ayutthaya, anthropoid, perpetuation, potential, embattled, carnatic, rale, vig,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2346 0.0671 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1467 0.0665 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1299 0.0655 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1669 0.0661 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0489 0.0663 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1330 0.0659 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1755 0.0663 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1517 0.0661 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1448 0.0088 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1142 0.0664 sec/batch
# Nearest to for: diligent, limpbizkit, gnp, recognizing, mcleod, the, throws, a,
# Nearest to which: takers, avars, toponyms, copernicanism, python, helge, completely, geocentric,
# Nearest to on: lanes, chanter, rann, swiftly, accounting, beryllium, jardine, stairs,
# Nearest to no: arrigo, centralised, senate, gladiators, synthesizer, rebel, gda, monoid,
# Nearest to b: abms, e, statesman, marianne, physicist, kath, barca, outline,
# Nearest to american: swaim, cyclist, harris, journalist, producer, crm, stevens, mesa,
# Nearest to however: exceptionally, centralised, buddies, composites, water, guid, in, bootlegs,
# Nearest to system: voting, soiled, macquarie, noncommutative, via, minicomputer, repository, onerous,
# Nearest to stage: beadwork, canvases, ares, blige, pythons, downbeat, wankel, craftsman,
# Nearest to centre: mothe, dobruja, linking, bisecting, quantization, hectares, ashcroft, aut,
# Nearest to notes: minter, immaturity, appreciating, modern, selfish, gard, koalas, guillain,
# Nearest to discovered: flowed, starvation, ceramics, equidistant, dissimilar, occultation, scalp, cvn,
# Nearest to mean: tautological, lecturers, cretans, metrizable, inlays, fridays, density, monsoon,
# Nearest to except: demarcation, dago, sigourney, ligeantia, casa, sinhala, atrahasis, vowels,
# Nearest to arts: sumatra, administers, exhibition, fundamentalist, schools, joked, hint, reasoner,
# Nearest to rise: ayutthaya, anthropoid, perpetuation, potential, embattled, calonne, coastlines, curve,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0786 0.0670 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0623 0.0660 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0995 0.0660 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0665 0.0662 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0676 0.0661 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0372 0.0662 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0869 0.0660 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0957 0.0660 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1176 0.0661 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0203 0.0664 sec/batch
# Nearest to for: diligent, the, gnp, a, recognizing, limpbizkit, throws, workflow,
# Nearest to which: takers, avars, copernicanism, toponyms, python, completely, afforded, arriving,
# Nearest to on: lanes, chanter, jardine, statecraft, stairs, swiftly, beryllium, mcdonnell,
# Nearest to no: arrigo, gladiators, upsilon, senate, monoid, synthesizer, acutely, yojimbo,
# Nearest to b: abms, e, kath, statesman, outline, bigg, infty, couturier,
# Nearest to american: swaim, harris, crm, producer, cyclist, mesa, phenomenon, silverman,
# Nearest to however: in, exceptionally, centralised, buddies, bootlegs, water, arminius, guid,
# Nearest to system: voting, macquarie, microprocessor, minicomputer, repository, via, files, soiled,
# Nearest to stage: beadwork, canvases, blige, pythons, ares, downbeat, craftsman, wankel,
# Nearest to centre: dobruja, mothe, linking, bisecting, quantization, hectares, buildings, lancers,
# Nearest to notes: minter, appreciating, selfish, modern, immaturity, koalas, guillain, impressions,
# Nearest to discovered: flowed, starvation, ceramics, equidistant, cvn, dissimilar, azores, impermanent,
# Nearest to mean: tautological, apollonius, inlays, monsoon, cretans, fridays, lecturers, canton,
# Nearest to except: demarcation, dago, casa, sigourney, ligeantia, sinhala, therefore, ribbentrop,
# Nearest to arts: sumatra, administers, exhibition, fundamentalist, schools, joked, hint, veneto,
# Nearest to rise: ayutthaya, potential, anthropoid, perpetuation, embattled, paternalism, outcomes, calonne,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0342 0.0678 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0064 0.0662 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0317 0.0661 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0849 0.0664 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0729 0.0664 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0700 0.0669 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0731 0.0665 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0819 0.0660 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0801 0.0663 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0367 0.0663 sec/batch
# Nearest to for: the, a, diligent, gnp, recognizing, limpbizkit, theoretic, commodities,
# Nearest to which: avars, takers, python, copernicanism, toponyms, geocentric, completely, afforded,
# Nearest to on: lanes, chanter, stairs, mcdonnell, beryllium, statecraft, both, jardine,
# Nearest to no: arrigo, acutely, yojimbo, monoid, meaningful, rebel, gladiators, prefer,
# Nearest to b: abms, e, bigg, kath, infty, statesman, nunn, outline,
# Nearest to american: swaim, harris, cyclist, mesa, producer, crm, islander, silverman,
# Nearest to however: exceptionally, centralised, in, water, bootlegs, buddies, composites, guid,
# Nearest to system: voting, noncommutative, repository, macquarie, via, alde, acquiring, soiled,
# Nearest to stage: beadwork, canvases, blige, ares, pythons, downbeat, wankel, ankle,
# Nearest to centre: dobruja, mothe, linking, quantization, bisecting, buildings, ashcroft, tripe,
# Nearest to notes: selfish, minter, appreciating, koalas, impressions, immaturity, guillain, modern,
# Nearest to discovered: flowed, ceramics, starvation, cvn, dissimilar, equidistant, occultation, scalp,
# Nearest to mean: tautological, apollonius, canton, monsoon, lecturers, inlays, cretans, persecute,
# Nearest to except: demarcation, dago, ligeantia, therefore, outputting, casa, allows, messianic,
# Nearest to arts: sumatra, administers, exhibition, fundamentalist, schools, joked, varsity, acad,
# Nearest to rise: ayutthaya, potential, outcomes, anthropoid, perpetuation, curve, paternalism, vig,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0458 0.0673 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0887 0.0665 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0761 0.0663 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0803 0.0663 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0950 0.0668 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0447 0.0674 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0844 0.0665 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0602 0.0662 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1145 0.0661 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0491 0.0660 sec/batch
# Nearest to for: diligent, the, catechumen, recognizing, khuzestan, limpbizkit, a, gnp,
# Nearest to which: avars, takers, toponyms, copernicanism, python, completely, geocentric, afforded,
# Nearest to on: lanes, chanter, stairs, swiftly, jardine, rann, calvary, statecraft,
# Nearest to no: arrigo, gladiators, upsilon, monoid, senate, synthesizer, centralised, proving,
# Nearest to b: abms, e, bigg, outline, kath, infty, nunn, statesman,
# Nearest to american: swaim, harris, cyclist, producer, journalist, crm, islander, phenomenon,
# Nearest to however: exceptionally, in, centralised, buddies, composites, arminius, tatsam, whoever,
# Nearest to system: voting, repository, noncommutative, macquarie, minicomputer, conferencing, annotated, bullpup,
# Nearest to stage: beadwork, canvases, blige, ares, pythons, craftsman, wankel, downbeat,
# Nearest to centre: mothe, dobruja, quantization, linking, bisecting, buildings, aut, tripe,
# Nearest to notes: minter, selfish, impressions, appreciating, immaturity, rhythmic, suru, modern,
# Nearest to discovered: flowed, ceramics, starvation, dissimilar, equidistant, cvn, sky, findings,
# Nearest to mean: tautological, persecute, cretans, canton, monsoon, apollonius, marquess, lecturers,
# Nearest to except: demarcation, dago, ligeantia, allows, atrahasis, casa, sigourney, messianic,
# Nearest to arts: sumatra, administers, exhibition, schools, fundamentalist, varsity, joked, giraud,
# Nearest to rise: ayutthaya, potential, perpetuation, calonne, anthropoid, curve, instructing, outcomes,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0513 0.0668 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0508 0.0661 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0428 0.0667 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0861 0.0666 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0390 0.0660 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1322 0.0666 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1278 0.0661 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0574 0.0659 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0223 0.0662 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0644 0.0658 sec/batch
# Nearest to for: the, diligent, a, gnp, catechumen, recognizing, by, limpbizkit,
# Nearest to which: avars, takers, python, toponyms, copernicanism, completely, geocentric, helge,
# Nearest to on: lanes, rann, stairs, jardine, swiftly, chanter, both, statecraft,
# Nearest to no: arrigo, senate, gladiators, upsilon, rodentia, monoid, synthesizer, acutely,
# Nearest to b: abms, e, statesman, kath, nunn, couturier, barca, sargent,
# Nearest to american: swaim, cyclist, harris, producer, journalist, islander, births, racial,
# Nearest to however: exceptionally, buddies, composites, borisovich, centralised, charming, in, sufism,
# Nearest to system: voting, repository, macquarie, noncommutative, satr, alde, minicomputer, braces,
# Nearest to stage: beadwork, canvases, pythons, blige, downbeat, ares, ankle, awry,
# Nearest to centre: mothe, dobruja, quantization, buildings, linking, bisecting, procession, aut,
# Nearest to notes: minter, koalas, selfish, modern, immaturity, impressions, rhythmic, gard,
# Nearest to discovered: flowed, ceramics, starvation, dissimilar, cvn, occultation, findings, azores,
# Nearest to mean: tautological, persecute, canton, monsoon, apollonius, cretans, marquess, barthes,
# Nearest to except: demarcation, ligeantia, dago, ribbentrop, sigourney, therefore, atrahasis, casa,
# Nearest to arts: sumatra, administers, exhibition, schools, varsity, giraud, fundamentalist, acad,
# Nearest to rise: ayutthaya, potential, perpetuation, curve, anthropoid, outcomes, instructing, embattled,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9783 0.0671 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0191 0.0664 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0316 0.0663 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0244 0.0662 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0915 0.0664 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0398 0.0557 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0105 0.0660 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9879 0.0659 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0287 0.0659 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9792 0.0662 sec/batch
# Nearest to for: diligent, the, a, recognizing, gnp, limpbizkit, by, theoretic,
# Nearest to which: avars, copernicanism, takers, toponyms, python, paired, completely, geocentric,
# Nearest to on: lanes, rann, statecraft, calvary, stairs, chanter, jardine, both,
# Nearest to no: arrigo, gladiators, senate, acutely, upsilon, tattoo, monoid, rebel,
# Nearest to b: abms, statesman, e, couturier, kath, four, valentin, nunn,
# Nearest to american: swaim, producer, phenomenon, cyclist, journalist, harris, musicologist, islander,
# Nearest to however: exceptionally, composites, buddies, in, water, centralised, arminius, borisovich,
# Nearest to system: voting, repository, minicomputer, bullpup, onerous, braces, satr, macquarie,
# Nearest to stage: beadwork, canvases, pythons, downbeat, blige, fiberglass, ankle, tic,
# Nearest to centre: dobruja, mothe, quantization, linking, buildings, bisecting, chattahoochee, arsenal,
# Nearest to notes: minter, impressions, gard, westview, selfish, immaturity, rhythmic, guillain,
# Nearest to discovered: flowed, starvation, ceramics, dissimilar, cvn, findings, suppressed, occultation,
# Nearest to mean: tautological, persecute, apollonius, monsoon, cretans, marquess, canton, density,
# Nearest to except: demarcation, dago, ligeantia, atrahasis, therefore, throws, sigourney, ribbentrop,
# Nearest to arts: sumatra, administers, exhibition, schools, acad, varsity, fundamentalist, giraud,
# Nearest to rise: ayutthaya, anthropoid, potential, perpetuation, curve, outcomes, embattled, calonne,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0035 0.0669 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9277 0.0659 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0274 0.0659 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0098 0.0665 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0205 0.0667 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9929 0.0662 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8952 0.0660 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9722 0.0665 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9796 0.0664 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9697 0.0666 sec/batch
# Nearest to for: the, a, gnp, diligent, recognizing, enzyme, ices, is,
# Nearest to which: avars, takers, copernicanism, python, toponyms, paired, completely, afforded,
# Nearest to on: lanes, stairs, calvary, statecraft, chanter, both, rann, jardine,
# Nearest to no: arrigo, populations, acutely, gladiators, senate, upsilon, retain, buddhas,
# Nearest to b: abms, e, kath, cones, rightarrow, statesman, bigg, algebras,
# Nearest to american: swaim, phenomenon, islander, crm, silverman, harris, producer, mesa,
# Nearest to however: exceptionally, buddies, in, composites, water, arminius, centralised, sufism,
# Nearest to system: voting, repository, macquarie, satr, minicomputer, alde, bullpup, annotated,
# Nearest to stage: beadwork, canvases, pythons, fiberglass, ankle, downbeat, awry, blige,
# Nearest to centre: dobruja, mothe, quantization, buildings, linking, bisecting, chattahoochee, systematics,
# Nearest to notes: rhythmic, impressions, gard, koalas, selfish, westview, bugle, guillain,
# Nearest to discovered: flowed, starvation, ceramics, cvn, sky, dissimilar, findings, occultation,
# Nearest to mean: tautological, marquess, monsoon, canton, persecute, density, apollonius, cretans,
# Nearest to except: demarcation, dago, ligeantia, atrahasis, throws, casa, messianic, therefore,
# Nearest to arts: sumatra, administers, exhibition, schools, varsity, fundamentalist, degrees, acad,
# Nearest to rise: ayutthaya, outcomes, potential, anthropoid, perpetuation, curve, paternalism, bjp,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9992 0.0676 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9929 0.0665 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9793 0.0665 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0241 0.0665 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0219 0.0663 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9779 0.0661 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0017 0.0665 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0196 0.0662 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9731 0.0660 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0144 0.0661 sec/batch
# Nearest to for: the, a, by, recognizing, diligent, enzyme, must, catechumen,
# Nearest to which: avars, python, copernicanism, takers, completely, toponyms, with, the,
# Nearest to on: lanes, both, stairs, jardine, rann, redefine, comico, calvary,
# Nearest to no: arrigo, monoid, upsilon, synthesizer, rodentia, retain, gladiators, proving,
# Nearest to b: abms, e, statesman, couturier, kath, nunn, sargent, barca,
# Nearest to american: swaim, harris, cyclist, islander, producer, phenomenon, silverman, journalist,
# Nearest to however: exceptionally, in, buddies, borisovich, howerd, composites, interactions, ulterior,
# Nearest to system: voting, repository, satr, noncommutative, annotated, bullpup, alde, densities,
# Nearest to stage: beadwork, canvases, ankle, pythons, downbeat, fiberglass, wankel, blige,
# Nearest to centre: mothe, dobruja, quantization, linking, buildings, bisecting, tripe, saloon,
# Nearest to notes: rhythmic, impressions, gard, style, westview, focussed, modern, koalas,
# Nearest to discovered: flowed, starvation, ceramics, cvn, dissimilar, findings, suppressed, sky,
# Nearest to mean: tautological, persecute, cretans, marquess, apollonius, monsoon, bellamy, lecturers,
# Nearest to except: demarcation, dago, throws, atrahasis, ligeantia, ribbentrop, limitations, interludes,
# Nearest to arts: sumatra, exhibition, administers, varsity, schools, acad, degrees, fundamentalist,
# Nearest to rise: ayutthaya, outcomes, perpetuation, potential, anthropoid, harmonically, curve, ensured,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0100 0.0673 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9803 0.0668 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9909 0.0662 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0093 0.0659 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9886 0.0662 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9959 0.0660 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9693 0.0663 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9338 0.0664 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9799 0.0666 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0254 0.0669 sec/batch
# Nearest to for: the, by, a, diligent, recognizing, gnp, from, now,
# Nearest to which: avars, in, with, the, python, toponyms, takers, copernicanism,
# Nearest to on: lanes, both, rann, ligeantia, april, accounting, comico, stairs,
# Nearest to no: arrigo, monoid, upsilon, retain, gladiators, synthesizer, populations, acutely,
# Nearest to b: abms, e, statesman, couturier, kath, barca, sargent, bigg,
# Nearest to american: swaim, phenomenon, islander, cyclist, harris, crm, publicly, producer,
# Nearest to however: in, exceptionally, buddies, other, borisovich, water, howerd, charming,
# Nearest to system: voting, satr, repository, noncommutative, minicomputer, bullpup, macquarie, eras,
# Nearest to stage: beadwork, canvases, pythons, ankle, ares, awry, craftsman, blige,
# Nearest to centre: mothe, dobruja, quantization, linking, buildings, bisecting, arsenal, saloon,
# Nearest to notes: impressions, gard, rhythmic, modern, koalas, bugle, cyrillic, appreciating,
# Nearest to discovered: flowed, starvation, ceramics, findings, cvn, dissimilar, boer, suppressed,
# Nearest to mean: tautological, persecute, marquess, apollonius, monsoon, cretans, averaging, bellamy,
# ...
# Nearest to which: in, with, the, and, by, a, of, is,
# Nearest to on: and, of, in, the, both, with, other, an,
# Nearest to no: reserves, prefer, emma, faith, charterer, utters, keyser, monoid,
# Nearest to b: statesman, abms, vilhelm, e, couturier, churchman, poet, kenji,
# Nearest to american: lila, musician, islander, births, hispanic, publicly, elway, musicologist,
# Nearest to however: in, exceptionally, agree, other, better, borisovich, these, actually,
# Nearest to system: systems, voting, operating, eras, satr, braces, into, pc,
# Nearest to stage: pythons, beadwork, camille, lunar, runner, ankle, downbeat, mothersbaugh,
# Nearest to centre: lewisham, mothe, tripe, quantization, dobruja, stockport, procession, alya,
# Nearest to notes: impressions, oclc, cyrillic, soli, typographic, westview, capitalization, annotations,
# Nearest to discovered: flowed, boer, ceramics, starvation, cvn, found, findings, antibody,
# Nearest to mean: nashville, bellamy, spokesperson, missing, travelogues, persecute, tautological, monsoon,
# Nearest to except: concluding, limitations, ligeantia, demarcation, may, therefore, nonstop, interludes,
# Nearest to arts: martial, administers, sumatra, bargello, exhibition, acad, varsity, ingenious,
# Nearest to rise: ensured, ayutthaya, outcomes, places, harmonically, pervasive, marvin, nazism,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8356 0.0675 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8489 0.0664 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8699 0.0665 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8595 0.0665 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8802 0.0665 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9124 0.0664 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8369 0.0662 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8173 0.0663 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8800 0.0661 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8838 0.0665 sec/batch
# Nearest to for: in, the, a, by, is, of, as, from,
# Nearest to which: in, with, the, by, is, a, and, of,
# Nearest to on: and, of, in, the, both, other, with, two,
# Nearest to no: reserves, faith, prefer, keyser, longa, synthesizer, monoid, charterer,
# Nearest to b: abms, e, statesman, kenji, vilhelm, tamils, algebras, seidel,
# Nearest to american: publicly, births, musician, lila, swaim, islander, musicologist, hispanic,
# Nearest to however: in, agree, exceptionally, other, borisovich, these, mpeg, better,
# Nearest to system: systems, voting, satr, braces, into, eras, operating, preu,
# Nearest to stage: pythons, camille, beadwork, symbiotic, lunar, runner, ankle, downbeat,
# Nearest to centre: mothe, lewisham, dobruja, quantization, stockport, tripe, procession, alya,
# Nearest to notes: impressions, oclc, soli, westview, typographic, cyrillic, capitalization, moods,
# Nearest to discovered: flowed, starvation, findings, found, ceramics, boer, antibody, panth,
# Nearest to mean: missing, bellamy, apollonius, nashville, travelogues, spokesperson, persecute, tautological,
# Nearest to except: may, concluding, demarcation, limitations, ligeantia, partial, dago, never,
# Nearest to arts: martial, administers, sumatra, exhibition, bargello, dartmouth, ingenious, giraud,
# Nearest to rise: ayutthaya, ensured, outcomes, places, nazism, calonne, harmonically, taraki,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8481 0.0671 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8739 0.0667 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8440 0.0663 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8269 0.0670 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8727 0.0665 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8456 0.0664 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9285 0.0665 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9150 0.0665 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9121 0.0662 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8138 0.0663 sec/batch
# Nearest to for: a, in, the, is, by, of, as, this,
# Nearest to which: in, with, the, by, a, is, and, an,
# Nearest to on: and, of, in, both, the, with, other, two,
# Nearest to no: reserves, keyser, synthesizer, faith, longa, charterer, erc, utters,
# Nearest to b: statesman, vilhelm, e, abms, poet, couturier, churchman, seidel,
# Nearest to american: births, publicly, musician, islander, lila, gabriel, hispanic, musicologist,
# Nearest to however: in, agree, exceptionally, borisovich, other, although, mpeg, these,
# Nearest to system: systems, satr, voting, eras, pc, braces, into, operating,
# Nearest to stage: pythons, lunar, symbiotic, beadwork, handily, camille, downbeat, teenager,
# Nearest to centre: mothe, lewisham, dobruja, triumph, stockport, procession, dung, quantization,
# Nearest to notes: impressions, oclc, cyrillic, iuris, soli, ellesmere, typographic, westview,
# Nearest to discovered: flowed, starvation, boer, ceramics, found, findings, azores, santo,
# Nearest to mean: missing, travelogues, nashville, bellamy, spokesperson, apollonius, tautological, monsoon,
# Nearest to except: may, concluding, limitations, demarcation, ligeantia, partial, never, interludes,
# Nearest to arts: martial, sumatra, combat, administers, ingenious, giraud, varsity, bargello,
# Nearest to rise: ayutthaya, places, ensured, omniglot, outcomes, historic, marvin, taraki,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8053 0.0675 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8606 0.0658 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7631 0.0664 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8999 0.0665 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8547 0.0660 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8599 0.0667 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9056 0.0258 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8257 0.0661 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8413 0.0663 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8335 0.0663 sec/batch
# Nearest to for: in, a, is, by, the, as, of, and,
# Nearest to which: in, with, the, a, and, by, is, as,
# Nearest to on: and, of, in, both, the, with, a, other,
# Nearest to no: reserves, faith, keyser, charterer, circulatory, hitter, monoid, synthesizer,
# Nearest to b: statesman, one, four, vilhelm, nine, american, e, eight,
# Nearest to american: musician, lila, publicly, b, islander, births, singer, gabriel,
# Nearest to however: in, exceptionally, other, agree, borisovich, anubis, actually, these,
# Nearest to system: systems, eras, satr, voting, braces, operating, into, pc,
# Nearest to stage: lunar, pythons, beadwork, camille, symbiotic, ankle, runner, deterministic,
# Nearest to centre: mothe, stockport, dobruja, lewisham, tripe, procession, chattahoochee, alya,
# Nearest to notes: impressions, oclc, iuris, soli, cyrillic, ellesmere, typographic, annotations,
# Nearest to discovered: flowed, boer, starvation, findings, ceramics, found, azores, antibody,
# Nearest to mean: missing, nashville, bellamy, monsoon, spokesperson, tautological, travelogues, apollonius,
# Nearest to except: concluding, may, ligeantia, demarcation, dago, interludes, limitations, never,
# Nearest to arts: martial, sumatra, administers, combat, involves, bargello, ingenious, giraud,
# Nearest to rise: ayutthaya, places, ensured, omniglot, nazism, outcomes, christianity, harmonically,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8275 0.0673 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8275 0.0665 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8409 0.0662 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7647 0.0665 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8543 0.0663 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8432 0.0663 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8814 0.0665 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7585 0.0662 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8184 0.0663 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8285 0.0667 sec/batch
# Nearest to for: in, the, a, is, of, by, as, and,
# Nearest to which: in, the, a, with, is, of, by, and,
# Nearest to on: and, of, the, in, a, both, other, an,
# Nearest to no: reserves, faith, circulatory, charterer, emma, prefer, monoid, about,
# Nearest to b: e, abms, statesman, mx, monosaccharides, algebras, tamils, hashimoto,
# Nearest to american: births, publicly, solanaceae, elway, islander, hispanic, lila, americans,
# Nearest to however: in, other, agree, exceptionally, these, as, borisovich, actually,
# Nearest to system: systems, eras, satr, into, pc, voting, operating, braces,
# Nearest to stage: lunar, pythons, runner, camille, symbiotic, ankle, mothersbaugh, beadwork,
# Nearest to centre: mothe, lewisham, stockport, triumph, alya, dobruja, quantization, saloon,
# Nearest to notes: impressions, oclc, soli, ellesmere, vibrates, cyrillic, circulates, losing,
# Nearest to discovered: flowed, boer, starvation, findings, ceramics, azores, found, millisecond,
# Nearest to mean: missing, nashville, spokesperson, bellamy, apollonius, monsoon, tautological, travelogues,
# Nearest to except: may, concluding, limitations, dago, ligeantia, interludes, partial, therefore,
# Nearest to arts: martial, sumatra, administers, combat, giraud, ingenious, varsity, involves,
# Nearest to rise: ayutthaya, ensured, omniglot, potential, outcomes, places, temperamental, christianity,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7572 0.0675 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8185 0.0683 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8459 0.0669 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8515 0.0678 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8334 0.0677 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8762 0.0665 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8406 0.0666 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8229 0.0664 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8488 0.0664 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8085 0.0665 sec/batch
# Nearest to for: in, a, is, the, of, as, by, this,
# Nearest to which: in, the, a, by, and, with, is, of,
# Nearest to on: and, of, in, the, both, other, a, an,
# Nearest to no: reserves, faith, erc, keyser, charterer, monoid, utters, emma,
# Nearest to b: e, abms, statesman, mx, hashimoto, barca, vigen, coprime,
# Nearest to american: publicly, births, lila, musician, islander, elway, solanaceae, hispanic,
# Nearest to however: in, agree, other, exceptionally, these, borisovich, this, actually,
# Nearest to system: systems, voting, satr, into, braces, eras, autonomic, necessary,
# Nearest to stage: lunar, pythons, ankle, mothersbaugh, camille, symbiotic, downbeat, runner,
# Nearest to centre: lewisham, alya, stockport, tripe, chang, quantization, mothe, triumph,
# Nearest to notes: impressions, oclc, soli, circulates, slurred, losing, ellesmere, vibrates,
# Nearest to discovered: flowed, found, findings, ceramics, boer, starvation, millisecond, archeological,
# Nearest to mean: missing, nashville, bellamy, spokesperson, chubut, tautological, monsoon, travelogues,
# Nearest to except: may, concluding, limitations, partial, ligeantia, demarcation, dago, never,
# Nearest to arts: martial, sumatra, administers, bargello, ingenious, giraud, combat, varsity,
# Nearest to rise: ayutthaya, ensured, omniglot, outcomes, harmonically, places, potential, christianity,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9019 0.0671 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8637 0.0662 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8178 0.0659 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8387 0.0661 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8352 0.0664 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8441 0.0659 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8463 0.0664 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8576 0.0660 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8268 0.0664 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8507 0.0665 sec/batch
# Nearest to for: in, a, the, of, is, this, by, as,
# Nearest to which: in, with, a, the, is, by, and, of,
# Nearest to on: and, of, in, the, a, both, other, three,
# Nearest to no: reserves, jargon, faith, charterer, erc, keyser, longa, insubstantial,
# Nearest to b: e, abms, mx, coprime, tamils, algebras, barca, jan,
# Nearest to american: publicly, births, islander, lila, phenomenon, solanaceae, elway, musician,
# Nearest to however: in, other, these, agree, exceptionally, this, as, borisovich,
# Nearest to system: systems, voting, into, eras, satr, autonomic, use, operating,
# Nearest to stage: pythons, lunar, sikhs, ankle, gypsy, teenager, camille, symbiotic,
# Nearest to centre: lewisham, triumph, alya, stockport, mothe, tripe, quantization, meda,
# Nearest to notes: impressions, oclc, vibrates, soli, circulates, slurred, ellesmere, losing,
# Nearest to discovered: that, found, findings, flowed, ceramics, boer, archeological, millisecond,
# Nearest to mean: nashville, missing, monsoon, bellamy, spokesperson, apollonius, chubut, travelogues,
# Nearest to except: may, never, concluding, ligeantia, partial, demarcation, dago, limitations,
# Nearest to arts: martial, administers, sumatra, varsity, giraud, ingenious, dartmouth, bargello,
# Nearest to rise: ayutthaya, ensured, outcomes, places, omniglot, christianity, potential, pervasive,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8498 0.0673 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8500 0.0664 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9156 0.0663 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9230 0.0660 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9073 0.0662 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8462 0.0663 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7941 0.0663 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8645 0.0660 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7196 0.0661 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8736 0.0663 sec/batch
# Nearest to for: in, is, a, the, of, by, as, this,
# Nearest to which: in, is, the, a, and, with, of, by,
# Nearest to on: and, of, in, the, a, both, other, an,
# Nearest to no: reserves, faith, charterer, hitter, about, circulatory, keyser, jargon,
# Nearest to b: e, statesman, one, four, american, hashimoto, vilhelm, trombonist,
# Nearest to american: musician, births, publicly, lila, islander, b, gabriel, musicologist,
# Nearest to however: in, agree, other, exceptionally, these, as, borisovich, anubis,
# Nearest to system: systems, voting, into, satr, eras, autonomic, operating, braces,
# Nearest to stage: pythons, lunar, mothersbaugh, sikhs, gypsy, supporting, ankle, symbiotic,
# Nearest to centre: lewisham, triumph, tripe, mothe, meda, stockport, chang, dobruja,
# Nearest to notes: impressions, oclc, soli, circulates, losing, ellesmere, slurred, vibrates,
# Nearest to discovered: flowed, found, was, findings, were, ceramics, that, azores,
# Nearest to mean: missing, nashville, spokesperson, monsoon, bellamy, travelogues, chubut, apollonius,
# Nearest to except: concluding, may, ligeantia, partial, limitations, never, nonstop, demarcation,
# Nearest to arts: martial, combat, sumatra, administers, taekwondo, giraud, kata, involves,
# Nearest to rise: ayutthaya, omniglot, ensured, places, huge, christianity, outcomes, pervasive,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8557 0.0674 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8542 0.0661 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
